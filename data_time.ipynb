# %% [markdown]
# <a href="https://colab.research.google.com/github/GOUTAM-RAM21/data-science-ml/blob/main/data_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head(5)
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig = df['number'].value_counts().plot.bar()
fig.set_title('Passengers travelling with')
fig
# Out:
# <Axes: title={'center': 'Passengers travelling with'}, xlabel='number'>

# %%
df['numic_number']=pd.to_numeric(df['number'],errors='coerce',downcast='integer')
df['number_categorical'] = np.where(df['numic_number'].isnull(),df['number'],np.nan)
df.head()
# Out:
#   Cabin            Ticket number  Survived  numic_number number_categorical
# 0   NaN         A/5 21171      5         0           5.0                NaN
# 1   C85          PC 17599      3         1           3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1           6.0                NaN
# 3  C123            113803      3         1           3.0                NaN
# 4   NaN            373450      A         0           NaN                  A

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)')
df['cabin_cat'] = df['Cabin'].str[0]

df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1419748691.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['cabin_num'] = df['Cabin'].str.extract('(\d+)')
#   Cabin            Ticket number  Survived  numic_number number_categorical  \
# 0   NaN         A/5 21171      5         0           5.0                NaN
# 1   C85          PC 17599      3         1           3.0                NaN
# 2   NaN  STON/O2. 3101282      6         1           6.0                NaN
# 3  C123            113803      3         1           3.0                NaN
# 4   NaN            373450      A         0           NaN                  A
#
#   cabin_num cabin_cat
# 0       NaN       NaN
# 1        85         C
# 2       NaN       NaN
# 3       123         C
# 4       NaN       NaN

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cabin_cat'>

# %%
#
df['ticket_num'] = df['Ticket'].apply(lambda s: s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],
                                   errors='coerce',
                                   downcast='integer')

# extract the first part of ticket as category
df['ticket_cat'] = df['Ticket'].apply(lambda s: s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan,
                              df['ticket_cat'])

df.head(20)
# Out:
#    Cabin            Ticket number  Survived  numic_number number_categorical  \
# 0    NaN         A/5 21171      5         0           5.0                NaN
# 1    C85          PC 17599      3         1           3.0                NaN
# 2    NaN  STON/O2. 3101282      6         1           6.0                NaN
# 3   C123            113803      3         1           3.0                NaN
# 4    NaN            373450      A         0           NaN                  A
# 5    NaN            330877      2         0           2.0                NaN
# 6    E46             17463      2         0           2.0                NaN
# 7    NaN            349909      5         0           5.0                NaN
# 8    NaN            347742      1         1           1.0                NaN
# 9    NaN            237736      A         1           NaN                  A
# 10    G6           PP 9549      1         1           1.0                NaN
# ...

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
# !pip install deep-translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator

# translate messages to english and store in a new column
time['msg_en'] = time['msg'].apply(lambda x: GoogleTranslator(source='auto', target='en').translate(x))

time.head()
# Out:
#                   date                                                msg  \
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#                                               msg_en
# 0                I am looking for a man for today 37
# 1  Bee guy is looking for a friend now !! SMS MMS...
# 2                                 Dnepr.m 43 Pozn.s.
# 3  Kyiv is looking for a d/w up to 45 now I am bo...
# 4       Zay I will never offend you love you!) Dasha

# %%
time
# Out:
#                     date                                                msg  \
# 0    2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1    2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2    2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3    2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4    2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
# ..                   ...                                                ...
# 995  2012-03-16 00:50:00     ПАРЕНЬ СДЕЛАЕТ  МАССАЖ ЖЕНЩИНАМ -066-877-32-44
# 996  2014-01-23 23:14:00            сельский п 23 ищу девушку для отношений
# 997  2012-10-15 23:37:00  Д+Д ДЛЯ серьезных отношений. Мой номер 093-156...
# 998  2012-06-21 23:34:00  7 ДНЕПР М.34 ПОЗ.С Д/Ж ДЛЯ ВСТРЕЧ.Т.098 809 15 14
# 999  2014-06-19 23:25:00          Парень поласкает девушке...  т.0662035584
#
#                                                 msg_en
# ...

# %%
time
# Out:
#                     date                                             msg_en
# 0    2013-12-15 00:50:00                I am looking for a man for today 37
# 1    2014-04-29 23:40:00  Bee guy is looking for a friend now !! SMS MMS...
# 2    2012-12-30 00:21:00                                 Dnepr.m 43 Pozn.s.
# 3    2014-11-28 00:31:00  Kyiv is looking for a d/w up to 45 now I am bo...
# 4    2013-10-26 23:11:00       Zay I will never offend you love you!) Dasha
# ..                   ...                                                ...
# 995  2012-03-16 00:50: